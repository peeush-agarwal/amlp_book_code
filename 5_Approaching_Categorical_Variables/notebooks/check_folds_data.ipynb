# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
df_folds = pd.read_csv('../input/train_folds.csv')
df_folds.head(10)
# Out:
#        id  bin_0  bin_1  bin_2 bin_3 bin_4 nom_0      nom_1    nom_2  \
# 0  242165    0.0    0.0    0.0     F     Y  Blue   Triangle  Axolotl
# 1  400150    0.0    0.0    0.0     T     Y  Blue  Trapezoid     Lion
# 2  159502    0.0    1.0    0.0     T     Y  Blue       Star      NaN
# 3   72350    0.0    0.0    0.0     F     Y   Red     Square     Lion
# 4  113743    0.0    1.0    0.0     F     Y   Red   Triangle      NaN
# 5   18041    0.0    0.0    0.0     F     N  Blue   Triangle  Hamster
# 6  486427    0.0    0.0    1.0     T     N   Red   Triangle  Axolotl
# 7  203135    0.0    0.0    0.0     F     N   Red     Circle      Dog
# 8  103659    0.0    0.0    0.0     F     Y   Red  Trapezoid     Lion
# 9  333982    0.0    0.0    1.0     F     N   Red    Polygon  Hamster
#
#         nom_3     nom_4      nom_5      nom_6      nom_7      nom_8  \
# 0       India  Theremin  85694456d  d892cdc98  a7059911d  a8009baf5
# 1       India   Bassoon  a3c2a3216  494b565c1  c79d2197d  d9148f8e7
# ...

# %%
df_folds['kfold'].value_counts()
# Out:
# 4    120000
# 3    120000
# 2    120000
# 1    120000
# 0    120000
# Name: kfold, dtype: int64

# %%
df_folds.groupby(['kfold'])['target'].value_counts()
# Out:
# kfold  target
# 0      0         97536
#        1         22464
# 1      0         97536
#        1         22464
# 2      0         97535
#        1         22465
# 3      0         97535
#        1         22465
# 4      0         97535
#        1         22465
# Name: target, dtype: int64
